# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonuenseo/eunseo/blob/master/10_4_xor_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##XOR 이해하기 with Keras

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
x_data = [[0, 0],
[0, 1],
[1, 0],
[1, 1]]
y_data = [[0],
[1],
[1],
[0]]
x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
model = Sequential()
model.add(Dense(2, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 2)                 6
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 6
# _________________________________________________________________
# activation_2 (Activation)    (None, 2)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# ...
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='model_xor.png', show_shapes=True)

# %%
#model.fit(x_data, y_data, batch_size=1, nb_epoch=1000)
#페이지에 안들어가져서 인쇄를 위해 주석처리했습니다.

# %%
hypothesis = model.predict_proba(x_data)
print(hypothesis)
# Out:
# [[0.05196986]
#  [0.9349074 ]
#  [0.4957498 ]
#  [0.51803607]]

# %%
predicted = hypothesis > 0.5
print(predicted)
# Out:
# [[False]
#  [ True]
#  [False]
#  [ True]]
